# %% [markdown]
# # __Yourname__
# *   Your Name
# *   Your School Name
# *   Your Group Number

# %% [markdown]
# # **Data Science Processes**
# 1. Business Understanding
# 2. Data Understanding
# 3. Data Cleaning
# 4. Data Transformation
# 5. Data Visualization
# 6. Report

# %% [markdown]
# ---

# %% [markdown]
# # 1.Business Understanding
# วิเคราะห์ข้อมูลคลิปวิดีโอ Youtube ช่อง [ออกกำลังกาย](https://www.youtube.com/channel/UCVQJZE_on7It_pEv6tn-jdA) ซึ่งเป็นช่องสำหรับคนที่รักสุขภาพและต้องการออกกำลังกายอย่างสม่ำเสมอ <br> ในช่องจะโพสคลิปวีดีโอทุกวัน  มีผู้ติดตามมากกว่า 7 แสน subscribers ยอดผู้ติดตามเพิ่มขึ้นอย่างรวดเร็ว <br>จึงต้องการวิเคราะห์ข้อมูลเพื่อ ต้องการทราบ ลักษณะของคลิปวีดีโอที่โพส, พฤติกรรมของผู้ติดตามคลิป

# %% [markdown]
# ## Hypothesis
#
#
# *   คนมักออกกำลังกายช่วงเย็นวันศุกร์ และเสาร์ อาทิตย์ ทำให้มียอดวิวสูงขึ้น ดังนั้นถ้าอยากให้มีผู้ติดตามอย่างสม่ำเสมอ ควรโพสวีดีโอ ช่วงเช้าวันศุกร์
# *   ผู้ติดตามคลิปน่าจะเป็นคนที่ออกกำลังกายด้วยตนเองที่บ้าน น่าจะชอบออกกำลังกายตามคลิปที่มีความยาวไม่เกิน 30 นาที
# *   คลิปที่มียอดวิวเยอะที่สุด คือคลิปแนะนำตัว

# %% [markdown]
# # 2.Data Understanding with Pandas

# %% [markdown]
# ## ข้อ 1 Import libraries ที่จำเป็นต่อการวิเคราะห์ข้อมูล

# %%
import warnings
warnings.filterwarnings("ignore")

# พิมพ์คำสั่ง ข้อ 1
# 1.1 library สำหรับจัดการข้อมูล
import pandas as pd

# 1.2 library plot graph พื้นฐาน
import matplotlib.pyplot as plt

#1.3 library seaborn
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# ## ข้อ 2 อ่านข้อมูล youtube.xlsx จาก folder dataset

# %%
# พิมพ์คำสั่ง ข้อ 2
df = pd.read_excel('/content/Dataset 6 - Youtube_channel.xlsx')

# %% [markdown]
# ---

# %% [markdown]
# ## ข้อ 3 ขนาดของข้อมูลมี กี่แถว กี่คอลัมน์

# %%
# พิมพ์คำสั่ง ข้อ 3
df.shape
# Out:
# (729, 12)

# %% [markdown]
# ---

# %% [markdown]
# ## ข้อ 4 แสดงข้อมูลแบบสุ่มทั้งหมด 10 แถว

# %%
# พิมพ์คำสั่ง ข้อ 4
df.sample(10)
# Out:
#      Unnamed: 0       date  length  views  calories workout_type  \
# 648         648 2019-10-25    46.0  28100     415.0     strength
# 376         376 2019-02-08    53.0  20708     480.0       cardio
# 16           16 2018-02-26    31.0  42130     410.0         hiit
# 93           93 2018-05-17    62.0  30694     625.0     strength
# 593         593 2019-09-07    13.0  23514       NaN     strength
# 366         366 2019-01-31    12.0  12982       NaN     strength
# 68           68 2018-04-22    22.0  13144       NaN      stretch
# 469         469 2019-05-08    43.0  31007     465.0       cardio
# 258         258 2018-10-24    53.0   9188     500.0     strength
# 618         618 2019-09-27    53.0  22212     500.0  hiit+cardio
#
#                area  days_since_posted posted_ago                  link  \
# 648      thigh+butt                 80   2 months  /watch?v=Z5POUeSA-rE
# 376            butt                339  11 months  /watch?v=l6i34hRXO9Y
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## ข้อ 5 แสดงชื่อคอลัมน์

# %%
# พิมพ์คำสั่ง ข้อ 5
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'length', 'views', 'calories', 'workout_type',
#        'area', 'days_since_posted', 'posted_ago', 'link', 'area2',
#        'workout_type2'],
#       dtype='object')

# %% [markdown]
# ขนาดของข้อมูลที่นำมาวิเคราะห์ มี xxx แถว  xxx คอลัมน์ <br>
#
# 1.   length : ความยาวของวิดีโอ / เป็นนาที
# 2.   calories : จำนวนแคลอรี่ที่เผาผลาญระหว่างการออกกำลังกายในวิดีโอ
# 3.   days_since_posted : จำนวนวันตั้งแต่โพสต์วิดีโอจนถึงตอนนี้
# 4.   date : วันที่โพสต์วิดีโอ
# 5.   workout_type : ประเภทของการออกกำลังกายที่มุ่งเน้น
# 6.   area : ออกกำลังกาย ส่วนไหนของร่างกาย
# 7.   Unnamed: 0 : เลขแสดงลำดับ
# 8.   posted_ago : โพสมาแล้ว
# 9.   link : ลิงค์ไปยังไฟล์วีดีโอ
# 10.   date : วันที่โพส
# 11.  View : จำนวนการดูวิดีโอ

# %% [markdown]
# ---

# %% [markdown]
# # __3.Data Cleaning & Transformation__

# %% [markdown]
# ## ข้อ 6 ลบ column "Unnamed: 0"

# %%
# ลบ column ที่ไม่ต้องการใช้งานออก 1 column ให้ใช้คำสั่งต่อไปนี้ในการลบ column
# df.drop('ชื่อcolumn', axis='columns')

# พิมพ์คำสั่ง ข้อ 6
df.drop('Unnamed: 0', axis='columns', inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## ข้อ 7 แสดงข้อมูลที่มีค่าว่าง

# %%
# พิมพ์คำสั่ง ข้อ 7
df.isnull().sum()
# Out:
# date                   0
# length                 0
# views                  0
# calories             141
# workout_type           0
# area                   0
# days_since_posted      0
# posted_ago             0
# link                   0
# area2                  0
# workout_type2          0
# dtype: int64

# %%
df[  df['calories'].isnull()   ]
# Out:
#           date     length  views  calories workout_type     area  \
# 1   2018-02-06  31.000000  75863       NaN  tabata+hiit     full
# 9   2018-02-20  29.000000   2149       NaN         hiit     full
# 10  2018-02-20   3.933333    526       NaN         hiit     full
# 12  2018-02-22  31.000000  46179       NaN     strength  butt+ab
# 14  2018-02-24  32.000000   2306       NaN     strength     full
# ..         ...        ...    ...       ...          ...      ...
# 699 2019-12-15  22.000000   7261       NaN      stretch     full
# 706 2019-12-22  22.000000   6762       NaN      stretch     full
# 713 2019-12-29  23.000000   7870       NaN      stretch     full
# 720 2020-01-05  24.000000   9180       NaN      stretch   hamstr
# 727 2020-01-12  22.000000   6683       NaN      stretch     full
#
#      days_since_posted posted_ago                  link  area2 workout_type2
# 1                  706     1 year  /watch?v=m40O_U8_4UE   full         Other
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## ข้อ 8 แก้ไขข้อมูลที่มีค่าว่าง

# %%
# เลือกวิธีที่เหมาะสมตามความคิดของนักศึกษา พร้อมให้เหตุผลประกอบ
# พิมพ์คำสั่ง ข้อ 8

# %% [markdown]
# ### <font color='blue'>**วิธีที่ 1** แทนค่าว่างด้วยค่าเฉลี่ย calories ของคลิปวีดีโอทั้งหมด</font>

# %%
cal_avg = round(df.calories.mean() , 0)
cal_avg
# Out:
# 474.0

# %%
df1 = df.copy()

# %%
df1['calories'].fillna(cal_avg, inplace=True)

# %%
df1.isnull().sum()
# Out:
# date                 0
# length               0
# views                0
# calories             0
# workout_type         0
# area                 0
# days_since_posted    0
# posted_ago           0
# link                 0
# area2                0
# workout_type2        0
# dtype: int64

# %% [markdown]
# ### <font color='blue'>**วิธีที่ 2** แทนค่าว่างด้วยค่าเฉลี่ย calories ของคลิปวีดีโอที่เป็น workout_type และ area ที่มีมากที่สุด</font>

# %%
df[['workout_type','views']].groupby(['workout_type']).agg('count').sort_values('views', ascending=False).head()
# Out:
#               views
# workout_type
# strength        324
# hiit             99
# stretch          87
# cardio           82
# hiit+cardio      28

# %%
df[['area','views']].groupby(['area']).agg('count').sort_values('views', ascending=False).head()
# Out:
#         views
# area
# full      410
# ab         80
# upper      30
# leg        28
# leg+ab     26

# %%
round(df[  df['workout_type'] =='strength'  ].calories.mean() , 0)
# Out:
# 467.0

# %%
round(df[   df['area'] =='full'  ].calories.mean() , 0)
# Out:
# 496.0

# %%
round(df[  ( df['workout_type'] =='strength' ) & ( df['area'] =='full' ) ].calories.mean() , 0)
# Out:
# 499.0

# %% [markdown]
# __หาค่าเฉลี่ยของ calories  --> Workout Type = 'Strength' และ Area = 'Full'__

# %%
cal_avg = round(df[  ( df['workout_type'] =='strength' ) & ( df['area'] =='full' ) ].calories.mean() , 0)
cal_avg
# Out:
# 499.0

# %%
df2 = df.copy()

# %%
df2['calories'].fillna(cal_avg, inplace=True)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0           0
# date                 0
# length               0
# views                0
# calories             0
# workout_type         0
# area                 0
# days_since_posted    0
# posted_ago           0
# link                 0
# area2                0
# workout_type2        0
# length_level         0
# dtype: int64

# %% [markdown]
# ### <font color='blue'>**วิธีที่ 3** แทนค่าว่างด้วยค่าเฉลี่ย calories ของคลิปวีดีโอที่เป็น workout_type ที่มีช่วงเวลาใกล้เคียงกัน</font>

# %%
df[['length']].describe()
# Out:
#            length
# count  729.000000
# mean    40.141724
# std     13.031237
# min      1.433333
# 25%     32.000000
# 50%     42.000000
# 75%     52.000000
# max     66.000000

# %%
df3 = df.copy()

# %%
cut_length = ['Short', 'Medium', 'Long', 'Very Long']
cut_bins = [0, 20, 40, 60, 100]
df3['length_level'] = pd.cut(df3['length'], bins=cut_bins, labels=cut_length)

# %%
df3.sample(5)
# Out:
#      Unnamed: 0       date  length  views  calories workout_type    area  \
# 318         318 2018-12-23    23.0   3678       NaN      stretch    full
# 204         204 2018-09-03    32.0  14875     250.0        pilat    full
# 302         302 2018-12-07    43.0  14805     480.0       cardio  leg+ab
# 272         272 2018-11-07    60.0  31247     810.0     strength    full
# 212         212 2018-09-10    32.0  36605     350.0     strength     leg
#
#      days_since_posted posted_ago                  link   area2 workout_type2  \
# 318                386     1 year  /watch?v=uOSjOsBs9iU    full       stretch
# 204                497     1 year  /watch?v=HPn9ZTnbS60    full         Other
# 302                402     1 year  /watch?v=DM4dFfk0eCs  leg+ab         Other
# 272                432     1 year  /watch?v=XMn0-Fs4CAU    full      strength
# 212                490     1 year  /watch?v=dCgmZ66Qa9k     leg      strength
#
#     length_level
# 318       Medium
# 204       Medium
# ...

# %%
df_null = df3[  df3['calories'].isnull()   ]

# %%
pd.pivot_table(df_null,
               index='workout_type',
               columns='length_level', 
               aggfunc={'views': 'count'},
               fill_value=0
               )
# Out:
#               views
# length_level  Short Medium Long Very Long
# workout_type
# cardio            0      1    1         0
# hiit              1      1    1         0
# hiit+cardio       2      1    0         0
# none              9      2    0         0
# strength         17      3    0         1
# stretch           2     85    0         0
# tabata+cardio     2      0    0         0
# tabata+hiit       0      1    0         0
# yoga              1      9    1         0

# %%
round(df[df['length_level']=='Medium']['calories'].mean(),0)
# Out:
# 365.0

# %%
for i in df['length_level'].unique():
    print(i, ' - ', round(df[df['length_level']==i]['calories'].mean(),0))
# Out:
# Medium  -  365.0
# Short  -  nan
# Long  -  495.0
# Very Long  -  651.0

# %%
idx = df[df['calories'].isnull()].index

# %%
idx
# Out:
# Int64Index([  1,   9,  10,  12,  14,  15,  17,  22,  27,  29,
#             ...
#             664, 671, 678, 685, 692, 699, 706, 713, 720, 727],
#            dtype='int64', length=141)

# %%
df.loc[idx]
# Out:
#      Unnamed: 0       date     length  views  calories workout_type     area  \
# 1             1 2018-02-06  31.000000  75863       NaN  tabata+hiit     full
# 9             9 2018-02-20  29.000000   2149       NaN         hiit     full
# 10           10 2018-02-20   3.933333    526       NaN         hiit     full
# 12           12 2018-02-22  31.000000  46179       NaN     strength  butt+ab
# 14           14 2018-02-24  32.000000   2306       NaN     strength     full
# ..          ...        ...        ...    ...       ...          ...      ...
# 699         699 2019-12-15  22.000000   7261       NaN      stretch     full
# 706         706 2019-12-22  22.000000   6762       NaN      stretch     full
# 713         713 2019-12-29  23.000000   7870       NaN      stretch     full
# 720         720 2020-01-05  24.000000   9180       NaN      stretch   hamstr
# 727         727 2020-01-12  22.000000   6683       NaN      stretch     full
#
# ...

# %%
df.groupby('length_level')['calories'].agg('mean')
# Out:
# length_level
# Short               NaN
# Medium       365.056250
# Long         495.318182
# Very Long    650.907407
# Name: calories, dtype: float64

# %%
for x in idx[:5]:
    print(x)
# Out:
# 1
# 9
# 10
# 12
# 14

# %%
df3.iat[1,2]
# Out:
# 31.0

# %%
df3.head(2)
# Out:
#    Unnamed: 0       date  length   views  calories workout_type  area  \
# 0           0 2018-02-01    31.0  197591     500.0         hiit  full
# 1           1 2018-02-06    31.0   75863       NaN  tabata+hiit  full
#
#    days_since_posted posted_ago                  link area2 workout_type2  \
# 0                711     1 year  /watch?v=Mcpyp9PRtU8  full          hiit
# 1                706     1 year  /watch?v=m40O_U8_4UE  full         Other
#
#   length_level
# 0       Medium
# 1       Medium

# %%
for x in idx: # only cal null
    if df3.loc[x, "length_level"] == 'Short':
        df3.iat[x, 4] = 0
    elif df.loc[x, "length_level"] == 'Medium':
        df3.iat[x, 4] = 365
    elif df3.loc[x, "length_level"] == 'Long':
        df3.iat[x, 4] = 495
    else:
        df3.iat[x,4] = 651

# %%
df3.loc[idx]
# Out:
#      Unnamed: 0       date     length  views  calories workout_type     area  \
# 1             1 2018-02-06  31.000000  75863     365.0  tabata+hiit     full
# 9             9 2018-02-20  29.000000   2149     365.0         hiit     full
# 10           10 2018-02-20   3.933333    526       0.0         hiit     full
# 12           12 2018-02-22  31.000000  46179     365.0     strength  butt+ab
# 14           14 2018-02-24  32.000000   2306     365.0     strength     full
# ..          ...        ...        ...    ...       ...          ...      ...
# 699         699 2019-12-15  22.000000   7261     365.0      stretch     full
# 706         706 2019-12-22  22.000000   6762     365.0      stretch     full
# 713         713 2019-12-29  23.000000   7870     365.0      stretch     full
# 720         720 2020-01-05  24.000000   9180     365.0      stretch   hamstr
# 727         727 2020-01-12  22.000000   6683     365.0      stretch     full
#
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0           0
# date                 0
# length               0
# views                0
# calories             0
# workout_type         0
# area                 0
# days_since_posted    0
# posted_ago           0
# link                 0
# area2                0
# workout_type2        0
# length_level         0
# dtype: int64

# %%
df3.loc[idx][df['length_level']=='Long']
# Out:
#      Unnamed: 0       date  length  views  calories workout_type  \
# 17           17 2018-02-27    42.0   2814     495.0         hiit
# 464         464 2019-05-03    43.0  32665     495.0       cardio
# 643         643 2019-10-20    60.0  10087     495.0         yoga
#
#                      area  days_since_posted posted_ago                  link  \
# 17                   full                685     1 year  /watch?v=NvdYeg6lMcU
# 464  shoulder+back+tricep                255   8 months  /watch?v=4HXq8o8sWpQ
# 643              full+hip                 85   2 months  /watch?v=mDlfpszzRmg
#
#      area2 workout_type2 length_level
# 17    full          hiit         Long
# 464  Other         Other         Long
# 643  Other         Other         Long

# %%
df3.loc[idx][df['length_level']=='Medium'].head(2)
# Out:
#    Unnamed: 0       date  length  views  calories workout_type  area  \
# 1           1 2018-02-06    31.0  75863     365.0  tabata+hiit  full
# 9           9 2018-02-20    29.0   2149     365.0         hiit  full
#
#    days_since_posted posted_ago                  link area2 workout_type2  \
# 1                706     1 year  /watch?v=m40O_U8_4UE  full         Other
# 9                692     1 year  /watch?v=PSF77PGC6Jg  full          hiit
#
#   length_level
# 1       Medium
# 9       Medium

# %%
df3.loc[idx][df['length_level']=='Short'].head(2)
# Out:
#     Unnamed: 0       date    length  views  calories workout_type  area  \
# 10          10 2018-02-20  3.933333    526       0.0         hiit  full
# 86          86 2018-05-10  8.633333   4321       0.0         none  none
#
#     days_since_posted posted_ago                  link  area2 workout_type2  \
# 10                692     1 year  /watch?v=_iFc_5iUzi8   full          hiit
# 86                613     1 year  /watch?v=ReP1q8S2pYY  Other         Other
#
#    length_level
# 10        Short
# 86        Short

# %% [markdown]
# ### <font color='blue'>**วิธีที่ 4** แทนค่าว่างด้วย 0</font>

# %%
# fill calories with short length_level with zero
df['calories'].fillna( 0 , inplace=True)

# %%
df.isnull().sum()
# Out:
# date                 0
# length               0
# views                0
# calories             0
# workout_type         0
# area                 0
# days_since_posted    0
# posted_ago           0
# link                 0
# length_level         0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # __4.Data Visualization__

# %% [markdown]
# ข้อ 9-15 เขียนคำสั่งเพื่อแสดงแผนภาพที่เหมาะสม พร้อมเขียนอธิบายแผนภาพ

# %% [markdown]
# # วิเคราะห์ข้อมูล แบบ Numerical data

# %% [markdown]
# ## ข้อ 9 แสดงการกระจายตัวของข้อมูล "ความยาวคลิป" และอธิบายประกอบ

# %%
df[['length']].describe()
# Out:
#            length
# count  729.000000
# mean    40.141724
# std     13.031237
# min      1.433333
# 25%     32.000000
# 50%     42.000000
# 75%     52.000000
# max     66.000000

# %%
# พิมพ์คำสั่ง ข้อ 9
sns.distplot(df['length'], bins=10) # kde=False, rug=True, hist=True
plt.show()

# %%
sns.boxplot(x = df['length'])
plt.show()

# %%
df[df['length']<10][['length','link','workout_type','area','views']]
# Out:
#        length                  link workout_type  area   views
# 10   3.933333  /watch?v=_iFc_5iUzi8         hiit  full     526
# 86   8.633333  /watch?v=ReP1q8S2pYY         none  none    4321
# 91   1.433333  /watch?v=itnn8B7xBPg         none  none    8362
# 99   1.866667  /watch?v=zpMQQTH-IHw         none  none    3742
# 208  8.450000  /watch?v=UrS5ZNhcF0I         none  none  152697

# %%
df[df['length'] < 10]['link'].map(lambda x: 'www.youtube.com'+x)
#df[df['length'] < 10]['link'].apply(lambda x: 'www.youtube.com'+x)
# Out:
# 10     www.youtube.com/watch?v=_iFc_5iUzi8
# 86     www.youtube.com/watch?v=ReP1q8S2pYY
# 91     www.youtube.com/watch?v=itnn8B7xBPg
# 99     www.youtube.com/watch?v=zpMQQTH-IHw
# 208    www.youtube.com/watch?v=UrS5ZNhcF0I
# Name: link, dtype: object

# %% [markdown]
# ข้อ 9  อธิบายคำตอบ <br>
# *   ความยาวสั้นที่สุดคือ 1 นาที
# *   ความยาวคลิปที่น้อยกว่า 10 นาที 80% (1 ใน 5) ไม่ใช่คลิปออกกำลังกาย
# *   ความยาวมากที่สุดคือ 66 นาที
# *   ความยาวคลิปวีดีโอ ส่วนใหญ่อยู่ในช่วง 40-55 นาที

# %% [markdown]
# ---

# %% [markdown]
# ## ข้อ 10 แสดงการกระจายตัวของข้อมูล "จำนวนคนดู" แต่ละคลิป และอธิบายประกอบ

# %%
# พิมพ์คำสั่ง ข้อ 10
# สามารถเลือกตัดข้อมูลบางส่วนออกได้เพื่อให้การวิเคราะห์ข้อมูลได้ชัดเจนยิ่งขึ้น

sns.boxplot( y='views', data=df)

# %%
sns.boxplot( y='views', data=df[df['views']<200000])

# %%
sns.boxplot( y='views', data=df[df['views']<100000])
# Out:
# <Axes: ylabel='views'>

# %%
df[df['views']>=200000][['length','link','workout_type','area','views']]
# Out:
#      length                  link workout_type        area    views
# 33     41.0  /watch?v=MaJKfBb0j6w         hiit        full   600979
# 37     31.0  /watch?v=jO1Yb0T4DuQ         hiit        full   288407
# 101    32.0  /watch?v=y-nbg7vNkcY     strength  thigh+butt  1298735
# 327    32.0  /watch?v=CR4X4XwlA_c         hiit        full   489310
# 329    33.0  /watch?v=rOf4tRtuvyA     strength       upper   337882
# 357    34.0  /watch?v=Qh_sBoA9Doo     strength  thigh+butt   207000

# %%
df[df['views']>=200000]['link'].apply(lambda x: 'www.youtube.com'+x)
# Out:
# 33     www.youtube.com/watch?v=MaJKfBb0j6w
# 37     www.youtube.com/watch?v=jO1Yb0T4DuQ
# 101    www.youtube.com/watch?v=y-nbg7vNkcY
# 327    www.youtube.com/watch?v=CR4X4XwlA_c
# 329    www.youtube.com/watch?v=rOf4tRtuvyA
# 357    www.youtube.com/watch?v=Qh_sBoA9Doo
# Name: link, dtype: object

# %% [markdown]
# ข้อ 10 อธิบายคำตอบ
#
#
# *   คลิปวีดีโอส่วนใหญ่มียอดวิวอยู่ที่ 30,000 คน
# *   ยอดวิวน้อยสุด คือ 526 คน ซึ่งปัจจุบันเพิ่มเป็น 919 คน
# *   มี 6 คลิป ที่ยอดวิว มากกว่า 200,000 คน (ซึ่งเป็นคลิปออกกำลังกาย)
# *   คลิปแนะนำตัวไม่ใช่คลิปที่มียอดวิวเยอะที่สุด (ผิดจากสมมติฐาน)
# *   คลิปที่มียอดวิวเยอะที่สุดคือ "30 Minute Butt and Thighs Burnout With Mini Band Workout 🔥Burn 300 Calories! 🔥" ปัจจุบันเพิ่มขึ้นไป 3ล้านวิว
#
# ข้อสมมติฐานเพิ่มเติมคือ ยอดวิวเยอะเพราะ MiniBand หรือไม่ (ต้องหาคำตอบต่อไป)

# %% [markdown]
# ---

# %% [markdown]
# # วิเคราะห์ข้อมูล แบบ Categorical data

# %% [markdown]
# ## ข้อ 12 คลิปวีดีโอส่วนใหญ่ออกกำลังกายส่วนใด (area)​

# %%
# ใช้คำสั่งกำหนดขนาดของแผนภาพให้เหมาะสม
# คำสั่งการปรับแกน x plt.xticks(rotation=90)

# พิมพ์คำสั่ง ข้อ 12
plt.figure(figsize=(25,7))
sns.countplot(x="area", data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,7))
sns.countplot(  x='area', 
              data=df , 
              order = df['area'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ข้อ 12 อธิบายคำตอบ

# %% [markdown]
# ---

# %% [markdown]
# # วิเคราะห์ข้อมูล แบบ Numerical 2 ตัวแปร

# %% [markdown]
# ## ข้อ 13 คนดูส่วนใหญ่ชอบดูคลิปวีดีโอที่มีความยาวเท่าใด

# %%
df3.head()
# Out:
#    Unnamed: 0       date  length   views  calories workout_type  area  \
# 0           0 2018-02-01    31.0  197591     500.0         hiit  full
# 1           1 2018-02-06    31.0   75863     365.0  tabata+hiit  full
# 2           2 2018-02-08    32.0   60328     350.0     strength    ab
# 3           3 2018-02-11    31.0   59741     430.0         hiit  full
# 4           4 2018-02-12    31.0   18515     285.0     strength  full
#
#    days_since_posted posted_ago                  link area2 workout_type2  \
# 0                711     1 year  /watch?v=Mcpyp9PRtU8  full          hiit
# 1                706     1 year  /watch?v=m40O_U8_4UE  full         Other
# 2                704     1 year  /watch?v=DWUupF-Sfyc    ab      strength
# 3                701     1 year  /watch?v=R3T3U9iFg0o  full          hiit
# 4                700     1 year  /watch?v=TLeMsJG30zU  full      strength
#
#   length_level
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4       Medium

# %%
# นักศึกษาสามารถตัด Outlier ออกได้ เพื่อให้การวิเคราะห์เหมาะสมยิ่งขึ้น
# พิมพ์คำสั่ง ข้อ 13 
plt.figure(figsize=(18,7))
sns.scatterplot(x='length', y='views', data=df)
# Out:
# <Axes: xlabel='length', ylabel='views'>

# %%
plt.figure(figsize=(18,7))
sns.scatterplot( 
    x='length', 
    y='views', 
    data=df[df['views']<100000])
plt.plot([40000]*70 , 'r')

# %%
# calories มีความสัมพันธ์กับยอดวิวหรือไม่ 
plt.figure(figsize=(18,7))
sns.scatterplot(x='calories', y='length', data=df, hue='view')
# Out:
# <Axes: xlabel='calories', ylabel='length'>

# %%
sns.lmplot(x='calories', y='length', data=df)

# %%
sns.lmplot(x='calories', y='views', data=df[df['views']<100000])

# %%
corr = df3.drop(columns=['Unnamed: 0']).corr()

# %%
sns.heatmap(corr, cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ข้อ 13 อธิบายคำตอบ

# %% [markdown]
# ---

# %% [markdown]
# ## ข้อ 14 ยอดคนดูคลิปในแต่ละวัน แตกต่างกันอย่างไร

# %%
df['date'][:5].dt.dayofweek
# Out:
# 0    3
# 1    1
# 2    3
# 3    6
# 4    0
# Name: date, dtype: int64

# %%
replace_values = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
df['day_of_week_num'] = df['date'].dt.dayofweek
df['day_of_week'] = df['day_of_week_num'].replace( to_replace = replace_values )
df.head()
# Out:
#    Unnamed: 0       date  length   views  calories workout_type  area  \
# 0           0 2018-02-01    31.0  197591     500.0         hiit  full
# 1           1 2018-02-06    31.0   75863       NaN  tabata+hiit  full
# 2           2 2018-02-08    32.0   60328     350.0     strength    ab
# 3           3 2018-02-11    31.0   59741     430.0         hiit  full
# 4           4 2018-02-12    31.0   18515     285.0     strength  full
#
#    days_since_posted posted_ago                  link area2 workout_type2  \
# 0                711     1 year  /watch?v=Mcpyp9PRtU8  full          hiit
# 1                706     1 year  /watch?v=m40O_U8_4UE  full         Other
# 2                704     1 year  /watch?v=DWUupF-Sfyc    ab      strength
# 3                701     1 year  /watch?v=R3T3U9iFg0o  full          hiit
# 4                700     1 year  /watch?v=TLeMsJG30zU  full      strength
#
#   length_level  day_of_week_num day_of_week
# 0       Medium                3    Thursday
# ...

# %%
# พิมพ์คำสั่ง ข้อ 14 
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

plt.figure(figsize=(18,7))
sns.boxplot( 
            x="day_of_week", 
            y="views", 
            data=df[df['views']<100000], 
            order=order)
# Out:
# <Axes: xlabel='day_of_week', ylabel='views'>

# %%
plt.figure(figsize=(18,7))
sns.boxplot( 
            x="day_of_week", 
            y="views", 
            data=df[df['views']>=100000], 
            order=order)

# %% [markdown]
# ข้อ 14 อธิบายคำตอบ

# %% [markdown]
# ---

# %% [markdown]
# # ข้อ 15 ตั้งคำถาม และสร้างแผนภาพ (หรือใช้คำสั่งอื่นๆ) เพื่อหาคำตอบ พร้อมอธิบาย

# %% [markdown]
# ---

# %% [markdown]
# # __6.Report__ ให้นักเรียน สรุปข้อมูลที่เป็นประโยชน์ที่ได้จากการทำ EDA มาอย่างน้อย 5 ข้อ ลง ใน PowerPoint

# %% [markdown]
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# 5.   List item
