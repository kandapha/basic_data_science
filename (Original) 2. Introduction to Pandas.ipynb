# %% [markdown]
# # __ชนิดของข้อมูลที่เกี่ยวข้องกับงาน Data Science__

# %% [markdown]
# ## **<font color='blue'>Non-Primitive Data Type</font>**

# %%
import numpy as np

# %%
data = [2,3,4,5,6,3,20]

# %%
sum = 0
for i in data:
    sum = sum + i
print(sum)
print(sum/len(data))
# Out:
# 97
# 16.166666666666668

# %%
np.mean(data)
# Out:
# 16.166666666666668

# %% [markdown]
# ## **<font color='blue'>Numpy Array</font>**

# %%
np.random.rand(4, 5).round(2) * 100
# Out:
# array([[87., 17., 82., 27., 50.],
#        [82., 83.,  8., 87., 44.],
#        [29., 47., 27., 92., 37.],
#        [60., 21.,  8., 23., 11.]])

# %%
X = [	[ 6, 7, 4, 5, 1 ],	
			[ 2, 8, 3, 6, 4 ],
			[ 1, 3, 2, 9, 6 ],
			[ 8, 9, 1, 7, 2 ] ]

# %%
npx = np.array(X)

# %%
npx[:]
# Out:
# array([[6, 7, 4, 5, 1],
#        [2, 8, 3, 6, 4],
#        [1, 3, 2, 9, 6],
#        [8, 9, 1, 7, 2]])

# %%
npx[:,:]
# Out:
# array([[6, 7, 4, 5, 1],
#        [2, 8, 3, 6, 4],
#        [1, 3, 2, 9, 6],
#        [8, 9, 1, 7, 2]])

# %%
npx[:2,:]
# Out:
# array([[6, 7, 4, 5, 1],
#        [2, 8, 3, 6, 4]])

# %%
npx[:2,:3]
# Out:
# array([[6, 7, 4],
#        [2, 8, 3]])

# %%
npx[:,:-1]
# Out:
# array([[6, 7, 4, 5],
#        [2, 8, 3, 6],
#        [1, 3, 2, 9],
#        [8, 9, 1, 7]])

# %%
npx[:,-1]
# Out:
# array([1, 4, 6, 2])

# %%
npx > 5
# Out:
# array([[ True,  True, False, False, False],
#        [False,  True, False,  True, False],
#        [False, False, False,  True,  True],
#        [ True,  True, False,  True, False]])

# %%
npx[ npx>5]
# Out:
# array([6, 7, 8, 6, 9, 6, 8, 9, 7])

# %% [markdown]
# ---

# %% [markdown]
# # __<font color='blue'>การจัดการข้อมูลด้วย Pandas</font>__

# %% [markdown]
# ## __<font color='blue'>1. List and Dictionary</font>__

# %%
X = [ 15, 12, 10, 22, 9 ]

# %%
type(X)
# Out:
# list

# %%
import pandas as pd

# %%
s = pd.Series(X)
s
# Out:
# 0    15
# 1    12
# 2    10
# 3    22
# 4     9
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
df = pd.DataFrame(X)
df
# Out:
#     0
# 0  15
# 1  12
# 2  10
# 3  22
# 4   9

# %%
df.columns = ['Age']

# %%
df
# Out:
#    Age
# 0   15
# 1   12
# 2   10
# 3   22
# 4    9

# %%
df['Name'] = ['Tim','John','Dan','Mali','Jack']
df
# Out:
#    Age  Name
# 0   15   Tim
# 1   12  John
# 2   10   Dan
# 3   22  Mali
# 4    9  Jack

# %% [markdown]
# **Series**

# %%
df['Name']
# Out:
# 0     Tim
# 1    John
# 2     Dan
# 3    Mali
# 4    Jack
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **DataFrame**

# %%
df[['Name']]
# Out:
#    Name
# 0   Tim
# 1  John
# 2   Dan
# 3  Mali
# 4  Jack

# %%
type(df[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # __<font color='blue'>การจัดการข้อมูลด้วย Pandas (ต่อ)</font>__

# %%
import numpy as np

# %%
name = ['Jane','John','Ashley','Mike','Emily','Jack','Catlin']
name
# Out:
# ['Jane', 'John', 'Ashley', 'Mike', 'Emily', 'Jack', 'Catlin']

# %%
dictionary_a = { 'name' : ['Jane','John','Ashley','Mike','Emily','Jack','Catlin'],
                 'grade':['A','A','C','B','B','C','B'],
                 'score':np.random.random(7).round(2) * 100,
                 'age':np.random.randint(15,22, size=7)}
dictionary_a
# Out:
# {'name': ['Jane', 'John', 'Ashley', 'Mike', 'Emily', 'Jack', 'Catlin'],
#  'grade': ['A', 'A', 'C', 'B', 'B', 'C', 'B'],
#  'score': array([59.,  8., 59., 90., 77., 52., 64.]),
#  'age': array([15, 16, 18, 18, 16, 19, 16])}

# %% [markdown]
# ## __2. Dictionary to Pandas DataFrame__

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'name':['Jane','John','Ashley','Mike','Emily','Jack','Catlin'],
    'grade':['A','A','C','B','B','C','B'],
    'score':np.random.random(7).round(2) * 100,
    'age':np.random.randint(15,22, size=7)
})

# %%
df
# Out:
#      name grade  score  age
# 0    Jane     A   25.0   16
# 1    John     A   19.0   18
# 2  Ashley     C   88.0   18
# 3    Mike     B   95.0   15
# 4   Emily     B   73.0   17
# 5    Jack     C   40.0   21
# 6  Catlin     B   53.0   16

# %%
df = pd.DataFrame({
    'name':['Jane','John','Ashley','Mike','Emily','Jack','Catlin'],
    'grade':['A','A','C','B','B','C','B'],
    'score':[78, 41, 97, 42, 31, 99, 46],
    'age': [20, 18, 16, 15, 21, 16, 18]
})

# %%
df.to_excel('output.xlsx')

# %%
df = pd.read_excel('output.xlsx')

# %%
df = df.drop(columns='Unnamed: 0')

# %%
type(df.name)
# Out:
# pandas.core.series.Series

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[:3][['name']]
# Out:
#      name
# 0    Jane
# 1    John
# 2  Ashley

# %%
df[1:4]
# Out:
#      name grade  score  age
# 1    John     A   35.0   21
# 2  Ashley     C   15.0   20
# 3    Mike     B   38.0   19

# %%
df[1:4].name
# Out:
# 1      John
# 2    Ashley
# 3      Mike
# Name: name, dtype: object

# %%
df[1:4][['name']]
# Out:
#      name
# 1    John
# 2  Ashley
# 3    Mike

# %%
df[1:4][['name','score']]
# Out:
#      name  score
# 1    John   35.0
# 2  Ashley   15.0
# 3    Mike   38.0

# %%
df[1:4]['name'].tolist()
# Out:
# ['John', 'Ashley', 'Mike']

# %%
df.nlargest(1, 'score')
# Out:
#      name grade  score  age
# 6  Catlin     B   58.0   18

# %% [markdown]
# ## __<font color='blue'>3. Using Pandas and Python to Explore the Data</font>__

# %% [markdown]
# ### __<font color='blue'>1. Logical Operators</font>__

# %%
df[df.name == 'Jane']
# Out:
#    Unnamed: 0  name grade  score  age
# 0           0  Jane     A     78   20

# %%
df[df.name < 'Jane']
# Out:
#      name grade  score  age
# 2  Ashley     C   42.0   20
# 4   Emily     B   44.0   20
# 5    Jack     C   89.0   17
# 6  Catlin     B   83.0   16

# %%
df[df.name > 'Jane']
# Out:
#    name grade  score  age
# 1  John     A   30.0   20
# 3  Mike     B   15.0   19

# %% [markdown]
# ### __<font color='blue'>2. Multiple Logical Operators</font>__

# %%
df[(df.score > 30.0) & (df.age == 18)]
# Out:
#      name grade  score  age
# 1    John     A     41   18
# 6  Catlin     B     46   18

# %%
df[(df.score > 30.0) | (df.age == 18)]
# Out:
#    Unnamed: 0    name grade  score  age
# 0           0    Jane     A     78   20
# 1           1    John     A     41   18
# 2           2  Ashley     C     97   16
# 3           3    Mike     B     42   15
# 4           4   Emily     B     31   21
# 5           5    Jack     C     99   16
# 6           6  Catlin     B     46   18

# %% [markdown]
# ### __<font color='blue'>3. Query</font>__

# %%
df.query( 'score > 30 and age == 18' )
# Out:
#      name grade  score  age
# 1    John     A     41   18
# 6  Catlin     B     46   18

# %%
df.query( 'score > 30 or age == 18' )
# Out:
#      name grade  score  age
# 0    Jane     A     78   20
# 1    John     A     41   18
# 2  Ashley     C     97   16
# 3    Mike     B     42   15
# 4   Emily     B     31   21
# 5    Jack     C     99   16
# 6  Catlin     B     46   18

# %%
df.query('grade == "B" and score > 30.0')
# Out:
#      name grade  score  age
# 3    Mike     B     42   15
# 4   Emily     B     31   21
# 6  Catlin     B     46   18

# %%
df.query('grade == "B" and score > 30.0')\
['name'].to_list()
# Out:
# ['Mike', 'Emily', 'Catlin']

# %% [markdown]
# ### __<font color='blue'>4. Isin</font>__

# %%
names = ['John','Catlin','Mike']
df[df.name.isin(names)]
# Out:
#      name grade  score  age
# 1    John     A   30.0   20
# 3    Mike     B   15.0   19
# 6  Catlin     B   83.0   16

# %% [markdown]
# ### __<font color='blue'>5. Str accessor</font>__

# %%
df[df.name.str.startswith('J')]
# Out:
#    Unnamed: 0  name grade  score  age
# 0           0  Jane     A     78   20
# 1           1  John     A     41   18
# 5           5  Jack     C     99   16

# %%
df[df.name.str.contains('y')]
# Out:
#      name grade  score  age
# 2  Ashley     C   42.0   20
# 4   Emily     B   44.0   20

# %% [markdown]
# ### __<font color='blue'>6. Loc and Iloc</font>__

# %% [markdown]
# - Loc: Select rows or columns using labels
# - Iloc: Select rows or columns using indices

# %%
df.iloc[3:5, 1:3] #rows 3 and 4, all columns
# Out:
#   grade  score
# 3     B   42.0
# 4     B   31.0

# %%
df.loc[3:5] #rows 3 and 4, all columns
# Out:
#     name grade  score  age
# 3   Mike     B   42.0   15
# 4  Emily     B   31.0   21
# 5   Jack     C   99.0   16

# %%
df.loc[3:5]['grade']
# Out:
# 3    B
# 4    B
# 5    C
# Name: grade, dtype: object

# %%
df.index = ['a','b','c','d','e','f','g']

# %%
df
# Out:
#      name grade  score  age
# a    Jane     A     78   20
# b    John     A     41   18
# c  Ashley     C     97   16
# d    Mike     B     42   15
# e   Emily     B     31   21
# f    Jack     C     99   16
# g  Catlin     B     46   18

# %%
df.loc['b':'d', :]
# Out:
#      name grade  score  age newscore
# b    John     A   38.0   18        b
# c  Ashley    C+   97.0   16        c
# d    Mike     B   42.0   15        b

# %%
df.score['b']
# Out:
# 38.0

# %%
df.iat[1,2]
# Out:
# 41

# %%
df.iat[1 , 2] = 38.0

# %%
df.iat[1,2]
# Out:
# 38.0

# %%
df['grade'].replace('C', 'C+', inplace=True)

# %%
df
# Out:
#      name grade  score  age
# 0    Jane     A   78.0   20
# 1    John     A   38.0   18
# 2  Ashley    C+   97.0   16
# 3    Mike     B   42.0   15
# 4   Emily     B   31.0   21
# 5    Jack    C+   99.0   16
# 6  Catlin     B   46.0   18

# %%
df['newscore'] = 'A'
df
# Out:
#      name grade  score  age newscore
# a    Jane     A     78   20        A
# b    John     A     41   18        A
# c  Ashley     C     97   16        A
# d    Mike     B     42   15        A
# e   Emily     B     31   21        A
# f    Jack     C     99   16        A
# g  Catlin     B     46   18        A

# %%
df['newscore'] = np.random.randint('1','10',size=7)
df
# Out:
#      name grade  score  age  newscore
# a    Jane     A     78   20         8
# b    John     A     41   18         5
# c  Ashley     C     97   16         5
# d    Mike     B     42   15         6
# e   Emily     B     31   21         8
# f    Jack     C     99   16         2
# g  Catlin     B     46   18         2

# %%
x = ['a','b','c']
df['newscore'] = np.random.choice(x, size=7)
df
# Out:
#      name grade  score  age newscore
# a    Jane     A     78   20        a
# b    John     A     41   18        a
# c  Ashley     C     97   16        b
# d    Mike     B     42   15        b
# e   Emily     B     31   21        a
# f    Jack     C     99   16        c
# g  Catlin     B     46   18        c

# %%
def new_score(val):
    if val >= 80:
        return 'A'
    if val >= 60:
        return 'B'
    if val >= 40:
        return 'C+'
    else:
        return 'C'

# %%
df['newscore'] = df['score'].map(new_score)
df
# Out:
#      name grade  score  age newscore
# 0    Jane     A   78.0   20        B
# 1    John     A   38.0   18        C
# 2  Ashley    C+   97.0   16        A
# 3    Mike     B   42.0   15       C+
# 4   Emily     B   31.0   21        C
# 5    Jack    C+   99.0   16        A
# 6  Catlin     B   46.0   18       C+

# %% [markdown]
# ## __<font color='blue'>4. DataFrame to SQLite</font>__

# %%
import sqlite3

# %%
conn = sqlite3.connect('mydata.db')

# %%
df
# Out:
#      name grade  score  age
# 0    Jane     A   42.0   16
# 1    John     A   41.0   15
# 2  Ashley     C   84.0   16
# 3    Mike     B   49.0   16
# 4   Emily     B   22.0   17
# 5    Jack     C   13.0   19
# 6  Catlin     B   26.0   20

# %%
df.to_sql('my_table', conn, if_exists='replace')

# %%
q = pd.read_sql_query('select * from my_table;', conn)
q
# Out:
#    index    name grade  score  age
# 0      0    Jane     A   42.0   16
# 1      1    John     A   41.0   15
# 2      2  Ashley     C   84.0   16
# 3      3    Mike     B   49.0   16
# 4      4   Emily     B   22.0   17
# 5      5    Jack     C   13.0   19
# 6      6  Catlin     B   26.0   20

# %%
q = pd.read_sql_query('select name, score from my_table;', conn)
q
# Out:
#      name  score
# 0    Jane   42.0
# 1    John   41.0
# 2  Ashley   84.0
# 3    Mike   49.0
# 4   Emily   22.0
# 5    Jack   13.0
# 6  Catlin   26.0

# %%
q = pd.read_sql_query('select name, score from my_table where score > 40;', conn)
q
# Out:
#      name  score
# 0    Jane   42.0
# 1    John   41.0
# 2  Ashley   84.0
# 3    Mike   49.0

# %%
q = pd.read_sql_query('select name, score, grade from my_table where grade = "B";', conn)
q
# Out:
#      name  score grade
# 0    Mike   49.0     B
# 1   Emily   22.0     B
# 2  Catlin   26.0     B

# %% [markdown]
# ### __5. Basic Visualization with Matplotlib library__

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
x = np.linspace(1,10,10)
y = x**2

# %%
plt.plot(x,x)
plt.show()

# %%
plt.plot(x,x)
plt.plot(x,x**2)
plt.show()

# %% [markdown]
# สร้างความแตกต่างแต่ละข้อมูล
#
#
# ในการอ่านทำความเข้าใจกราฟที่ประกอบไปด้วยหลายข้อมูลอาจทำให้เกิดความสับสนได้ เราสามารถสร้างความแตกต่างของการแสดงผลแต่ละข้อมูลได้ผ่านการเปลี่ยน สี ลักษณะเส้นกราฟ และสัญลักษณ์ ของแต่ละข้อมูล
#
#
# ผ่านการระบุ string ที่ใส่สัญลักษณ์ของแต่ละค่าเอาไว้ เช่น กราฟเส้นสีดำใช้ 'k' กราฟเส้นทึบใช้ '-' กราฟที่มีสัญลักษณ์ข้าวหลามตัดใช้ 'D' เขียนรวมได้เป็น 'k-D' และระบุเป็น parameter เอาไว้ใน plt.plot() ใช้งานในลักษณะดังนี้
#
# [สัญลักษณ์เพิ่มเติม](https://jakevdp.github.io/PythonDataScienceHandbook/04.06-customizing-legends.html)

# %%
plt.plot(x,x,'r-o')
plt.plot(x,x**2)
plt.show()

# %% [markdown]
# การใส่แกน x,y
#
# เพื่อเพิ่มความเข้าใจค่าที่ระบุในแกน เราสามารถแปะ label สำหรับแกน x,y ได้ด้วยคำสั่ง .xlabel() .ylabel() ที่รับค่า string ที่เก็บชื่อที่ต้องการเอาไว้

# %%
plt.plot(x,x,'r-o')
plt.plot(x,x**2)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.plot(x,x,'k-D',label='y = x')
plt.plot(x,x**2,label='y = x**2')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# __ชื่อแต่ละข้อมูล__
#
# เราสามารถแสดงผลหลายข้อมูลบนกราฟได้พร้อมกัน ซึ่งอาจทำให้เกิดความสับสนเกี่ยวกับข้อมูลที่แสดงอยู่ได้ ซึ่งการระบุชื่อของตัวข้อมูลหรือ label เพิ่มเติมจากสี ลักษณะเส้นกราฟ และสัญลักษณ์ พิเศษจะช่วยให้กราฟเข้าใจได้ง่ายขึ้น
#
# __label__
# ในการระบุชื่อข้อมูลที่ต้องการ เราจะใช้การระบุ label เป็น parameter สำหรับ plt.plot() เพื่อตั้งชื่อให้กับข้อมูล ซึ่ง label จะแสดงผลผ่าน legend ซึ่งต้องเขียนคำสั่งเพื่อแสดงผล legend
#
# __legend__
# คือ กล่องข้อความที่แสดงชื่อของแต่ละข้อมูล โดยการระบุผ่านสี ลักษณะเส้นกราฟ และสัญลักษณ์ ซึ่งจะแสดงต่อเมื่อใช้คำสั่ง plt.legend()
#
# • ตำแหน่งของ legend
#
# สามารถปรับแต่งได้โดยใช้ parameter loc= ตามด้วย string ที่ระบุค่าการกำหนดตำแหน่งที่มีให้เลือก ดังนี้ best, upper right, upper left, lower left, lower right, right, center left, center right, lower center, upper center, center
#
# ซึ่งหากไม่ระบุตำแหน่งจะใช้ default เป็น best คือให้ matplotlib เลือกให้ ว่าควรอยู่ที่ใด

# %%
plt.plot(x,x,'k-D',label='y = x')
plt.plot(x,x**2,label='y = x**2')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# การใส่ชื่อกราฟ
#
#
# ใช้คำสั่ง plt.title() ที่รับค่า string ที่เก็บข้อมูลชื่อที่ต้องการตั้ง และสามารถใส่ parameter fontsize= เพื่อกำหนดขนาดชื่อกราฟ

# %%
plt.title("Graphs showing y = x and y = x**2",fontsize=15)
plt.plot(x,x,'k-D',label='y = x')
plt.plot(x,x**2,label='y = x**2')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### __Categorical data__

# %% [markdown]
# #### __1. Bar chart (verticle)__

# %% [markdown]
# __กราฟแท่ง__
#
# ใช้คำสั่ง .bar() สำหรับกราฟแท่งแนวตั้ง และ .barh() สำหรับกราฟแท่งแนวนอน ในการสร้างโดยรับค่า x, y เป็น parameter หลัก และสามารถใช้ร่วมกับการตั้งชื่อกราฟ สร้างความแตกต่างแต่ละข้อมูล ตั้งชื่อข้อมูล และอื่นๆ ได้
#
# __ข้อมูลที่ใช้__
# กราฟแท่งเหมาะกับการใช้เปรียบเทียบข้อมูลที่ไม่ต่อเนื่องกัน เช่น ยอดขายของสินค้าแต่ละประเภท

# %%
x = ['shirts','pants','shorts','shoes']
y = [1000,1200,800,1800]

# %%
plt.bar(x,y)
plt.title('Sales by category')
plt.ylabel('sales revenue')
plt.xlabel('item type')
plt.show()

# %% [markdown]
# #### __2. Bar chart (horizontal)__

# %%
plt.barh(x,y)
plt.title('Sales by category')
plt.ylabel('item type')
plt.xlabel('sales revenue')
plt.show()

# %% [markdown]
# ### __Numerical data__

# %% [markdown]
# #### __1. Histogram__

# %% [markdown]
# __Histogram__
#
# เป็นกราฟที่ใช้เพื่อดูความถี่ของการเกิดขึ้นของข้อมูล จะเหมาะกับข้อมูลที่มีจำนวนมาก ซึ่ง Histogram จะมีการแบ่งข้อมูลออกเป็น bins และนับการเกิดของแต่ละ bins เพื่อนับความถี่ของแต่ละ bins ที่เกิดขึ้นและสร้างเป็นกราฟลักษณะคล้ายกราฟแท่ง
#
#
# __ข้อมูลที่ใช้__
# เราจะสร้างข้อมูล จำนวน 100 ข้อมูล จากการสุ่มจากคำสั่ง np.random.normal() ที่สุ่มข้อมูลมาจาก normal distribution
#
# __สร้าง histogram__
#
# ใช้คำสั่ง .hist() รับค่า x และจำนวน bins หรือจำนวนแท่งกราฟที่ต้องการ โดย plt.hist จะทำการแบ่งข้อมูลเป็นกลุ่มต่างๆ จำนวนเท่ากับ bins และทำการนับแต่ละ bins

# %%
x = np.random.normal(size=100)
plt.title('Data Distribution')
plt.hist(x,bins=20)
plt.xlabel('y value')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# #### __2. Box Plot__

# %% [markdown]
# __Box Plot__
#
# เป็นกราฟที่ใช้ดูการกระจายตัวของข้อมูล โดยมีพื้นฐานการคำนวนจากการวัด Quartile ซึ่งทำการเรียงข้อมูลทั้งหมดจากน้อยไปมาก และแบ่งข้อมูลออกเป็น 4 ส่วน Q1 Q2 Q3 Q4 โดยมีกล่องตรงกลาง แสดงพื้นที่ Q1 ถึง Q3 มีเส้นสีส้มแสดงค่า median และระความยาวของกล่องตรงกลางเรียกว่าค่า IQR (Interquartile-range, Q3-Q1) และมีเส้นตรงขีดออกไปยังค่า Q1-(1.5 x IQR) ในด้านที่ค่าน้อยกว่า และ Q3+(1.5 x IQR) ในด้านที่ค่ามากกว่า โดยหากข้อมูลใดมีค่ามากกว่า หรือน้อยกว่าจุดสิ้นสุดของเส้นตรงดังกล่าว เราจะเรียกข้อมูลเหล่านั้นว่า Outlier
#
#
# __ข้อมูลที่ใช้__
#
# ใน boxplot เหมาะกับข้อมูลจำนวนมาก ที่เราต้องการดูการกระจายตัว ในตัวอย่างจะสร้างเลขจำนวน 100 ตัวจากการสุ่มจาก normal distribution

# %%
x = np.random.normal(size=100)
plt.boxplot(x)
plt.xlabel('100 data points from Normal Distribution')
plt.ylabel('data values')
plt.show()

# %% [markdown]
# #### __3. Scatter Plot (Numerical with 2 variables)__

# %% [markdown]
# __Scatter Plot__
#
# นิยมใช้แสดงผลข้อมูลเพื่อดูความสัมพันธ์ระหว่างแกน x,y หรือ ระหว่างในชุดข้อมูลเอง การสร้างใช้คำสั่ง .scatter() ที่รับค่า x, y

# %%
plt.scatter(np.linspace(1,100,100),np.random.normal(size=100))
plt.show()

# %% [markdown]
# ### __Sub Graph__

# %% [markdown]
# __การสร้างหลายกราฟ__
#
# ใช้การสร้างพื้นที่ในการสร้างกราฟที่แบ่งแต่ละกราฟออกเป็นส่วนๆ และทำการใช้คำสั่งสร้างกราฟที่เราเรียนไปต่างๆ สร้างกราฟลงไป
#
# __สร้างพื้นที่การทำงาน__
#
# ด้วยคำสั่ง plt.subplots() โดยให้กำหนด nrows= กำหนดจำนวนแถว ncols= กำหนดจำนวนกราฟแต่ละแถว และ figsize= กำหนดขนาดของกราฟทั้งหมดเป็น tuple ที่ประกอบไปด้วย (ความกว้าง,ความสูง)
#
# เช่น การสร้างพื้นที่เพื่อสร้าง 6 กราฟ โดยแบ่งเป็น 3 แถว แถวละ 2 กราฟ โดยมีขนาด 8 x 8 โดยเราจะสร้างตัวแปร fig, axes มา unpack ข้อมูลที่ได้จาก คำสั่ง .subplots()

# %%
fig, axes = plt.subplots(nrows=3,ncols=2,figsize=(8,8))
plt.tight_layout()

# %% [markdown]
# __ใส่กราฟลงพื้นที่__
#
# โดยใช้ข้อมูลในตัวแปร axes ตามด้วยการระบุตำแหน่งตามหลังด้วยสัญลักษณ์ [แถว,คอลัมน์] เพื่อระบุตำแหน่งของกราฟที่ต้องการใส่ ตำแหน่งแรกเริ่มจาก 0
#
# เช่น การใส่กราฟเส้นลงไปที่ตำแหน่ง [0,0] หรือ ซ้ายบน และตามด้วยคำสั่ง .plot() (เพื่อสร้างกราฟเส้น) และเราจะใช้คำสั่ง plt.tight_layout() เพื่อปรับขนาดให้ตัวอักษรไม่ทับกันโดยอัตโนมัติ

# %%
fig, axes = plt.subplots(nrows=3,ncols=2,figsize=(8,8))

axes[0,0].set_title("Graphs showing y = x and y = x**2")
axes[0,0].plot(np.linspace(1,10,10),np.linspace(1,10,10),'k-D',label='y = x')
axes[0,0].plot(np.linspace(1,10,10),np.linspace(1,10,10)**2,label='y = x**2')
axes[0,0].legend(loc='best')
axes[0,0].set_xlabel('x')
axes[0,0].set_ylabel('y')

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=3,ncols=2,figsize=(8,8))

axes[0,0].set_title("Graphs showing y = x and y = x**2")
axes[0,0].plot(np.linspace(1,10,10),np.linspace(1,10,10),'k-D',label='y = x')
axes[0,0].plot(np.linspace(1,10,10),np.linspace(1,10,10)**2,label='y = x**2')
axes[0,0].legend(loc='best')
axes[0,0].set_xlabel('x')
axes[0,0].set_ylabel('y')

axes[0,1].set_title('Sales by category')
axes[0,1].bar(['shirts','pants','shorts','shoes'],[1000,1200,800,1800])
axes[0,1].set_ylabel('sales revenue')
axes[0,1].set_xlabel('item type')

axes[1,0].set_title('Sales by category')
axes[1,0].barh(['shirts','pants','shorts','shoes'],[1000,1200,800,1800])
axes[1,0].set_ylabel('item type')
axes[1,0].set_xlabel('sales revenue')

axes[1,1].set_title('Data Distribution')
axes[1,1].hist(np.random.normal(size=100),bins=20)
axes[1,1].set_xlabel('value')
axes[1,1].set_ylabel('frequency')

axes[2,0].set_title('Scatter Plot')
axes[2,0].scatter(np.linspace(1,100,100),np.random.normal(size=100))
axes[2,0].set_xlabel('x')
axes[2,0].set_ylabel('Values')

axes[2,1].set_title('Boxplot')
axes[2,1].boxplot(np.random.normal(size=100))
axes[2,1].set_xlabel('100 Randomly Generated')
axes[2,1].set_ylabel('Values')

plt.tight_layout()

# %% [markdown]
# ## 6.Visualization with **Pandas**

# %% [markdown]
# 1. .area()
# 2. .bar()
# 3. .barh()
# 4. .box()
# 5. .hexbin()
# 6. .hist()
# 7. .kde()
# 8. .density()
# 9. .line()
# 10. .pie()
# 11. .scatter()

# %%
x = np.random.randint(1,100,size=10)
y = np.random.randint(1,100,size=10)
z = np.random.randint(1,100,size=10)

# %%
df = pd.DataFrame({'col_1':x, 'col_2':y, 'col_3':z})
df.head()
# Out:
#    col_1  col_2  col_3
# 0     53     16     35
# 1     71     57      5
# 2     38     41     13
# 3     22     57     31
# 4     50     65     50

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots=True, figsize=(4, 4));

# %%
df.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['col_1']].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['col_1','col_2']].plot(kind="hist")
plt.xticks([0,100])
plt.yticks([0,5])
# Out:
# ([<matplotlib.axis.YTick at 0x7f346f9155e0>,
#   <matplotlib.axis.YTick at 0x7f346f8b9df0>],
#  [Text(0, 0, ''), Text(0, 0, '')])

# %%
df.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
a = ['item_1','item_2','item_3','item_4','item_5','item_6','item_7','item_8','item_9','item_10']
b = np.random.randint(10,500,size=10)

# %%
df['col_4'] = a
df['col_5'] = b
df.head()
# Out:
#    col_1  col_2  col_3   col_4  col_5
# 0     53     16     35  item_1    462
# 1     71     57      5  item_2    499
# 2     38     41     13  item_3    347
# 3     22     57     31  item_4    349
# 4     50     65     50  item_5    460

# %%
df.plot(x='col_4', y='col_5', kind="bar", rot=45, fontsize=10)
# Out:
# <AxesSubplot:xlabel='col_4'>

# %%
sorted = df.sort_values(by='col_5', ascending=False)
sorted.plot(x='col_4', y='col_5', kind='bar')
# Out:
# <AxesSubplot:xlabel='col_4'>

# %%
df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df[['col_1']].plot.hist();

# %%
df[['col_1','col_2','col_3','col_5']].diff().hist()
# Out:
# array([[<AxesSubplot:title={'center':'col_1'}>,
#         <AxesSubplot:title={'center':'col_2'}>],
#        [<AxesSubplot:title={'center':'col_3'}>,
#         <AxesSubplot:title={'center':'col_5'}>]], dtype=object)

# %%
df[['col_1','col_2','col_3','col_5']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[['col_1','col_2','col_3','col_5']].boxplot()
# Out:
# <AxesSubplot:>

# %%
df[['col_1','col_2','col_3','col_5']].plot.box(vert=True, positions=[1, 2, 3, 4])
# Out:
# <AxesSubplot:>

# %%
df[['col_1','col_2','col_3']].plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df[['col_1','col_2','col_3','col_5']].plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='col_1', y='col_3')
# Out:
# <AxesSubplot:xlabel='col_1', ylabel='col_3'>

# %%
from seaborn.rcmod import palettes
df.plot.scatter(x="col_1", y="col_3", c='col_5')
# Out:
# <AxesSubplot:xlabel='col_1', ylabel='col_3'>

# %%
ax=df.plot.scatter(x="col_1", y="col_3", color="red", marker="*", s=100)
df.plot.scatter(x="col_2", y="col_3", color="orange", s=100, ax=ax)
# Out:
# <AxesSubplot:xlabel='col_2', ylabel='col_3'>

# %% [markdown]
# ## 7.Basic Visualization with __Seaborn__ library

# %% [markdown]
# __เปลี่ยน style ด้วย Seaborn__
#
# สามารถทำได้โดยการใช้ style ที่ถูกสร้างไว้สำเร็จรูป ซึ่ง seaborn เป็นหนึ่งใน library ที่ใช้ตกแต่ง รวมไปถึง plot กราฟในรูปแบบต่างๆ ที่เราจะใช้เพื่อเปลี่ยนรูปแบบการแสดงผล
#
# เราจะใช้คำสั่ง sns.set_style() และกำหนด parameter style= ซึ่งมีให้เลือกเบื้องต้น white, dark, whitegrid, darkgrid, ticks สามารถใช้งานได้ดังนี้
# [เรียนรู้กราฟชนิดต่างๆ](https://www.python-graph-gallery.com/)

# %%
import seaborn as sns
sns.set_style(style='whitegrid')

fig, axes = plt.subplots(nrows=3,ncols=2,figsize=(8,8))

axes[0,0].set_title("Graphs showing y = x and y = x**2")
axes[0,0].plot(np.linspace(1,10,10),np.linspace(1,10,10),'k-D',label='y = x')
axes[0,0].plot(np.linspace(1,10,10),np.linspace(1,10,10)**2,label='y = x**2')
axes[0,0].legend(loc='best')
axes[0,0].set_xlabel('x')
axes[0,0].set_ylabel('y')

axes[0,1].set_title('Sales by category')
axes[0,1].bar(['shirts','pants','shorts','shoes'],[1000,1200,800,1800])
axes[0,1].set_ylabel('sales revenue')
axes[0,1].set_xlabel('item type')

axes[1,0].set_title('Sales by category')
axes[1,0].barh(['shirts','pants','shorts','shoes'],[1000,1200,800,1800])
axes[1,0].set_ylabel('item type')
axes[1,0].set_xlabel('sales revenue')

axes[1,1].set_title('Data Distribution')
axes[1,1].hist(np.random.normal(size=100),bins=20)
axes[1,1].set_xlabel('value')
axes[1,1].set_ylabel('frequency')

axes[2,0].set_title('Scatter Plot')
axes[2,0].scatter(np.linspace(1,100,100),np.random.normal(size=100))
axes[2,0].set_xlabel('x')
axes[2,0].set_ylabel('Values')

axes[2,1].set_title('Boxplot')
axes[2,1].boxplot(np.random.normal(size=100))
axes[2,1].set_xlabel('100 Randomly Generated')
axes[2,1].set_ylabel('Values')

plt.tight_layout()

# %%
import seaborn as sns

# %%
sns.lineplot(x = "col_3", y = "col_1", data=df)
# Out:
# <AxesSubplot:xlabel='col_3', ylabel='col_1'>

# %%
df['year'] = np.linspace(2013,2022,10).astype(int)
df
# Out:
#    col_1  col_2  col_3    col_4  col_5  year
# 0     53     16     35   item_1    462  2013
# 1     71     57      5   item_2    499  2014
# 2     38     41     13   item_3    347  2015
# 3     22     57     31   item_4    349  2016
# 4     50     65     50   item_5    460  2017
# 5     96     90     58   item_6    310  2018
# 6     71      9     33   item_7     22  2019
# 7     58     31     10   item_8    204  2020
# 8     77     12     94   item_9     72  2021
# 9     82     59     86  item_10    146  2022

# %%
sns.lineplot(x = np.linspace(1,10,10), y = "col_1", data=df)
# Out:
# <AxesSubplot:ylabel='col_1'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x ='year', y ='col_1', data = df,  
            palette ='plasma')
# Out:
# <AxesSubplot:xlabel='year', ylabel='col_1'>

# %%
sns.displot(df['col_1'])
